# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

MAIN_DIR = ".."
DATA_DIR = os.path.join(MAIN_DIR, "data")

testcase_df = pd.read_csv(os.path.join(DATA_DIR, "queries", "MSK LLM Fictitious Case Files.csv"))
testcase_df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /mnt/c/Users/QUAN/Desktop/lbp_mri/notebooks/EDA_testcases.ipynb Cell 1 line 9
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/mnt/c/Users/QUAN/Desktop/lbp_mri/notebooks/EDA_testcases.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> MAIN_DIR = ".."
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/mnt/c/Users/QUAN/Desktop/lbp_mri/notebooks/EDA_testcases.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a> DATA_DIR = os.path.join(MAIN_DIR, "data")
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/mnt/c/Users/QUAN/Desktop/lbp_mri/notebooks/EDA_testcases.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a> testcase_df = pd.read_csv(os.path.join(DATA_DIR, "queries", "MSK LLM Fictitious Case Files 061023.csv"))
# ...

# %%
testcase_df["Appropriateness Category"].value_counts()

# %%
# Appropriateness Distribution
plt.figure()
sns.countplot(testcase_df["Appropriateness Category"])
# Out:
# <Axes: xlabel='count', ylabel='Appropriateness Category'>

# %%
# Appropriateness Distribution
plt.figure()
sns.countplot(testcase_df["Difficulty"])
# Out:
# <Axes: xlabel='count', ylabel='Difficulty'>
